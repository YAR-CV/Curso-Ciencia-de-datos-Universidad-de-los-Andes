# %% [markdown]
# [![Banner-Preparaci-n.png](https://i.postimg.cc/q7vd5LZP/Banner-Preparaci-n.png)](https://postimg.cc/QFwPBpDm)

# %% [markdown]
# # Integración y preparación de datos
#
# ## Actividad: Transformaciones de texto usando spacy
#
# Hola, en este Notebook veremos como convertir nuestro texto utilizando la libreria spacy. Spacy es una poderosa libreria que nos permite hacer transformaciones de texto mediante una serie de comandos relativamente sencillos, que veremos a continuacion. Veremos como spacy nos ayuda a tokenizar, lematizar, y convertir las cadenas de texto en atributos numericos dicientes para ingresarlos a tu modelo de prediccion.
#
# Como contexto, vamos a trabajar con los datos de Booking.com, y un listado de hoteles, y su respectiva descripcion en la plataforma de Booking. Las descripciones serán usadas para ilustrar la forma en que spacy transforma nuestro texto en atributos numéricos.

# %% [markdown]
# **Autor:** John Calvo, Santiago Fajardo
#
# js.calvo125@uniandes.edu.co, s.fajardot@uniandes.edu.co

# %% [markdown]
# ### 1. ¿Qué es tokenización en NLP?
# Durante el procesamiento, spaCy primero tokeniza el texto, i.e. segmenta el texto en palabras, puntuación y así sucesivamente. Esto es posible aplicando reglas específicas a cada lenguaje. Por ejemplo, puntuación al final de una oración debe ser una separación, mientras que en palabras como “U.K” se debe mantener en una sola palabra. Cada Doc consiste de tokens individuales y podemos iterar sobre ellos.
#
# Para esto, primero vamos a cargar la libreria spacy. Para instalara, primero ejecuta el comando:
#
# pip install spacy
#
# Una vez instalado, ejecuta el comando:
#
# python -m spacy download es_core_news_md
#
# Esto instalará el modelo necesario para nuestra tranformación.

# %%
import spacy #Libreria a utilizar
import pandas as pd

# %%
nlp = spacy.load("es_core_news_md") #Cargamos el modelo NLP en español de Spacy

# %% [markdown]
# Ahora, podemos cargar nuestros datos de Booking.com que puedes encontrar en https://www.kaggle.com/camesruiz/booking-hotel-descriptions-spanish/version/1 gracias a Camilo Ruiz

# %%
#col_names = ["ID","name","location","description","rating","image","link"]
dataframe = pd.read_csv("hotelsb_df_es (utf-8).csv", sep=',', skip_blank_lines=True, quotechar='"', encoding='utf-8')
dataframe.head(3)
# Out:
#    ID                              name                         location  \
# 0   0  Hotel Marina Suites By GH Suites  Bocagrande, Cartagena de Indias
# 1   1       Hotel Fenix Beach Cartagena                     Tierra Bomba
# 2   2          Mercure Bogota Calle 100                Chapinero, Bogotá
#
#                                          description  rating  \
# 0  \r\nEl Hotel Marina Suites By GH Suites se enc...     7.9
# 1  \r\nEl Hotel Fenix ​​Beach Cartagena se encuen...     8.8
# 2  \r\nEl Mercure Bogotá Calle 100 se encuentra e...     8.9
#
#                                                image  \
# 0  https://cf.bstatic.com/xdata/images/hotel/squa...
# 1  https://cf.bstatic.com/xdata/images/hotel/squa...
# 2  https://cf.bstatic.com/xdata/images/hotel/squa...
#
#                                                 link
# 0  https://www.booking.com/hotel/co/marina-suite....
# 1  https://www.booking.com/hotel/co/playa-vista.e...
# 2  https://www.booking.com/hotel/co/atton-bogota-...

# %%
# creamos un documento utilizando el primer registro
doc = nlp(dataframe.iloc[0].description) #Oracion formada con el diccionario de palabras NLP
for token in doc:
    print(token.text)
# Out:
# El
# Hotel
# Marina
# Suites
# By
# GH
# Suites
# se
# encuentra
# en
# Cartagena
# de
# Indias
# ,
# a
# solo
# 200
# metros
# de
# la
# playa
# .
# Ofrece
# servicio
# de
# habitaciones
# ,
# un
# centro
# de
# negocios
# y
# conexión
# Wi-Fi
# gratuita
# .
#
#
# Las
# habitaciones
# disponen
# de
# aire
# acondicionado
# ,
# TV
# ,
# baño
# privado
# con
# ducha
# y
# aseo
# ,
# suelo
# de
# baldosa
# y
# armario
# .
#
#
# Hay
# restaurantes
# locales
# con
# servicio
# de
# envío
# de
# comida
# ,
# y
# se
# pueden
# encontrar
# sitios
# para
# comer
# a
# menos
# de
# 5
# minutos
# a
# pie
# .
#
#
# El
# Hotel
# Marina
# Suites
# By
# GH
# Suites
# se
# halla
# a
# solo
# 1
# km
# del
# centro
# histórico
# de
# Cartagena
# de
# Indias
# ,
# a
# 200
# metros
# del
# centro
# comercial
# Nao
# y
# a
# 7
# km
# del
# aeropuerto
# internacional
# Rafael
# Núñez
# .

# %%
# Vamos a guardar nuestros documentos transformados en una lista

nlp_docs = []

for _, hotel in dataframe.iterrows():
    doc = nlp(hotel.description)
    nlp_docs.append(doc)
    
nlp_docs[3]
# Out:
# Este hotel está situado en Bogotá, a 5 minutos a pie del centro de convenciones de Corferias y a 5 minutos en coche de la embajada de Estados Unidos. Ofrece habitaciones confortables con conexión Wi-Fi gratuita.
# Las habitaciones del Hotel Pasajero Suites disponen de baño privado con ducha y agua caliente las 24 horas y TV LED Smart.
# El hotel cuenta con recepción 24 horas con consigna de equipaje y sirve cada mañana un desayuno americano con café colombiano recién hecho.
# El Pasajero Suites está a 10 minutos en coche del aeropuerto internacional El Dorado y a 15 minutos en coche del Museo del Oro.

# %% [markdown]
# ### 2. ¿Qué sigue después de tokenizar nuestra oración?
#
# Después de la tokenización, spaCy puede realizar un parse y taggear un documento dado. Acá es donde un [pipeline]( https://spacy.io/usage/spacy-101#pipelines) entrenado y sus modelos estadísticos son usados, lo cual permite a spaCy realizar predicciones de que tag o etiqueta aplica al contexto. Un componente entrenado incluye datos binarios que es producida al momento de mostrarle a un sistema suficientes ejemplos, para realizar predicciones que son generales a lo largo del lenguaje. Por ejemplo, una palabra seguido de ‘el’ es más probable que sea un sustantivo.
#
# Anotaciones lingüísticas están disponibles como atributos del token. Como otras librerías de NLP, spaCy codifica todos los Strings a [valores de hash]( https://latam.kaspersky.com/blog/que-es-un-hash-y-como-funciona/2806/#:~:text=10%20Abr%202014-,Una%20funci%C3%B3n%20criptogr%C3%A1fica%20hash%2D%20usualmente%20conocida%20como%20%E2%80%9Chash%E2%80%9D%2D,tendr%C3%A1%20siempre%20la%20misma%20longitud.) para reducir el uso de memoria e incrementar la eficiencia. Así que para obtener la representación en caracteres utilizamos `_` al final del nombre
#
# Veamos un ejemplo

# %%
for token in nlp_docs[3]: #Iteramos sobre cada token y extraemos los siguientes atributos de un documento
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
#
#  SPACE _SP
#  False False
# Este Este DET DET__Gender=Masc|Number=Sing|PronType=Dem det Xxxx True True
# hotel hotel NOUN NOUN__Gender=Masc|Number=Sing nsubj xxxx True False
# está estar AUX AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin cop xxxx True True
# situado situar ADJ ADJ__Gender=Masc|Number=Sing|VerbForm=Part ROOT xxxx True False
# en en ADP ADP__AdpType=Prep case xx True True
# Bogotá Bogotá PROPN PROPN obl Xxxxx True False
# , , PUNCT PUNCT__PunctType=Comm punct , False False
# a a ADP ADP__AdpType=Prep case x True False
# 5 5 NUM NUM__NumForm=Digit|NumType=Card nummod d False False
# minutos minuto NOUN NOUN__Gender=Masc|Number=Plur obl xxxx True False
# a a ADP ADP__AdpType=Prep case x True False
# pie pie INTJ NOUN fixed xxx True False
# del del ADP ADP__AdpType=Preppron fixed xxx True True
# centro centrar NOUN NOUN__Gender=Masc|Number=Sing nmod xxxx True False
# de de ADP ADP__AdpType=Prep case xx True True
# convenciones convención NOUN NOUN__Gender=Fem|Number=Plur nmod xxxx True False
# de de ADP ADP__AdpType=Prep case xx True True
# Corferias Corferias PROPN PROPN nmod Xxxxx True False
# y y CCONJ CCONJ cc x True False
# a a ADP ADP__AdpType=Prep case x True False
# 5 5 NUM NUM__NumForm=Digit|NumType=Card nummod d False False
# minutos minuto NOUN NOUN__Gender=Masc|Number=Plur conj xxxx True False
# en en ADP ADP__AdpType=Prep case xx True True
# coche coche NOUN NOUN__Gender=Masc|Number=Sing nmod xxxx True False
# de de ADP ADP__AdpType=Prep case xx True True
# la lo DET DET__Definite=Def|Gender=Fem|Number=Sing|PronType=Art det xx True True
# embajada embajada NOUN NOUN__Gender=Fem|Number=Sing nmod xxxx True False
# de de ADP ADP__AdpType=Prep case xx True True
# Estados Estados PROPN PROPN nmod Xxxxx True True
# Unidos Unidos PROPN PROPN flat Xxxxx True False
# . . PUNCT PUNCT__PunctType=Peri punct . False False
# Ofrece Ofrece VERB VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin ROOT Xxxxx True False
# habitaciones habitación NOUN NOUN__Gender=Fem|Number=Plur obj xxxx True False
# confortables confortable ADJ ADJ__Number=Plur amod xxxx True False
# con con ADP ADP__AdpType=Prep case xxx True True
# conexión conexión NOUN NOUN__Gender=Fem|Number=Sing obl xxxx True False
# Wi-Fi Wi-Fi PROPN PROPN nmod Xx-Xx False False
# gratuita gratuito ADJ ADJ__Gender=Fem|Number=Sing amod xxxx True False
# . . PUNCT PUNCT__PunctType=Peri punct . False False
#
#
#  SPACE _SP
#  False False
# Las Las DET DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art det Xxx True True
# habitaciones habitación NOUN NOUN__Gender=Fem|Number=Plur nsubj xxxx True False
# del del ADP ADP__AdpType=Preppron case xxx True True
# Hotel Hotel PROPN PROPN nmod Xxxxx True False
# Pasajero Pasajero PROPN PROPN flat Xxxxx True False
# Suites Suites PROPN PROPN flat Xxxxx True False
# disponen disponer AUX VERB__Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin ROOT xxxx True False
# de de ADP ADP__AdpType=Prep case xx True True
# baño bañar NOUN NOUN__Gender=Masc|Number=Sing obj xxxx True False
# privado privar ADJ ADJ__Gender=Masc|Number=Sing|VerbForm=Part amod xxxx True False
# con con ADP ADP__AdpType=Prep case xxx True True
# ducha duchar NOUN NOUN__Gender=Fem|Number=Sing obl xxxx True False
# y y CCONJ CCONJ cc x True False
# agua aguar NOUN NOUN__Gender=Fem|Number=Sing conj xxxx True False
# caliente calentar ADJ ADJ__Number=Sing amod xxxx True False
# las los DET DET__Definite=Def|Gender=Fem|Number=Plur|PronType=Art det xxx True True
# 24 24 NUM NUM__NumForm=Digit|NumType=Card nummod dd False False
# horas hora NOUN NOUN__Gender=Fem|Number=Plur obj xxxx True True
# y y CCONJ CCONJ cc x True False
# TV TV PROPN PROPN conj XX True False
# LED LED PROPN PROPN flat XXX True False
# Smart Smart PROPN PROPN flat Xxxxx True False
# . . PUNCT PUNCT__PunctType=Peri punct . False False
#
#
#  SPACE _SP
#  False False
# El El DET DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art det Xx True True
# hotel hotel NOUN NOUN__Gender=Masc|Number=Sing nsubj xxxx True False
# cuenta contar VERB VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin ROOT xxxx True True
# con con ADP ADP__AdpType=Prep case xxx True True
# recepción recepción NOUN NOUN__Gender=Fem|Number=Sing obl xxxx True False
# 24 24 NUM NUM__NumForm=Digit|NumType=Card nummod dd False False
# horas hora NOUN NOUN__Gender=Fem|Number=Plur obj xxxx True True
# con con ADP ADP__AdpType=Prep case xxx True True
# consigna consignar NOUN NOUN__Gender=Fem|Number=Sing obj xxxx True False
# de de ADP ADP__AdpType=Prep case xx True True
# equipaje equipaje NOUN NOUN__Gender=Masc|Number=Sing nmod xxxx True False
# y y CCONJ CCONJ cc x True False
# sirve servir VERB VERB__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin conj xxxx True False
# cada cada DET DET__Number=Sing|PronType=Tot det xxxx True True
# mañana mañana NOUN NOUN__Gender=Fem|Number=Sing obl xxxx True False
# un uno DET DET__Definite=Ind|Gender=Masc|Number=Sing|PronType=Art det xx True True
# desayuno desayunar NOUN NOUN__Gender=Masc|Number=Sing obj xxxx True False
# americano americano ADJ ADJ__Gender=Masc|Number=Sing amod xxxx True False
# con con ADP ADP__AdpType=Prep case xxx True True
# café café NOUN NOUN__Gender=Masc|Number=Sing nmod xxxx True False
# colombiano colombiano ADJ ADJ__Gender=Masc|Number=Sing amod xxxx True False
# recién recién ADV ADV advmod xxxx True False
# hecho hacer ADJ ADJ__Gender=Masc|Number=Sing|VerbForm=Part amod xxxx True True
# . . PUNCT PUNCT__PunctType=Peri punct . False False
#
#
#  SPACE _SP
#  False False
# El El DET DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art det Xx True True
# Pasajero Pasajero PROPN PROPN nsubj Xxxxx True False
# Suites Suites PROPN PROPN flat Xxxxx True False
# está estar AUX AUX__Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin cop xxxx True True
# a a ADP ADP__AdpType=Prep case x True False
# 10 10 NUM NUM__NumForm=Digit|NumType=Card nummod dd False False
# minutos minuto NOUN NOUN__Gender=Masc|Number=Plur ROOT xxxx True False
# en en ADP ADP__AdpType=Prep case xx True True
# coche coche NOUN NOUN__Gender=Masc|Number=Sing nmod xxxx True False
# del del ADP ADP__AdpType=Preppron case xxx True True
# aeropuerto aeropuerto NOUN NOUN__Gender=Masc|Number=Sing nmod xxxx True False
# internacional internacional ADJ ADJ__Number=Sing amod xxxx True False
# El El DET DET__Definite=Def|Gender=Masc|Number=Sing|PronType=Art det Xx True True
# Dorado Dorado PROPN PROPN appos Xxxxx True False
# y y CCONJ CCONJ cc x True False
# a a ADP ADP__AdpType=Prep case x True False
# 15 15 NUM NUM__NumForm=Digit|NumType=Card nummod dd False False
# minutos minuto NOUN NOUN__Gender=Masc|Number=Plur conj xxxx True False
# en en ADP ADP__AdpType=Prep case xx True True
# coche coche NOUN NOUN__Gender=Masc|Number=Sing nmod xxxx True False
# del del ADP ADP__AdpType=Preppron case xxx True True
# Museo Museo PROPN PROPN nmod Xxxxx True False
# del del ADP ADP__AdpType=Preppron case xxx True True
# Oro Oro PROPN PROPN flat Xxx True False
# . . PUNCT PUNCT__PunctType=Peri punct . False False
#
#
#  SPACE _SP
#  False False

# %% [markdown]
# Como observamos, obtenemos los siguientes atributos de cada palabra en la oración: El texto, el texto en forma base, la nomenclatura de la palabra (verbo, sustantivo, …), un Tag correspondiente a la nomenclatura, la dependencia de la palabra en la oración, la forma que tiene (Si empieza con mayúscula o si hay una mayúscula en el medio), si el token es Alpha numérico y si la palabra hace parte de las palabras más usadas en el lenguaje.  Un ejemplo de lo que obtenemos lo vemos en la siguiente tabla:
#
#
# | TEXT    	| LEMMA   	| POS   	| TAG 	| DEP      	| SHAPE 	| ALPHA 	| STOP  	|
# |---------	|---------	|-------	|-----	|----------	|-------	|-------	|-------	|
# | Este      | Este      | DET       | ...   | det       | Xxxx      | True      | True      |
# | hotel     | hotel     | NOUN      | ...   | ROOT      | xxxx      | True      | False     |
# | está      | est       | PROPN     | PROPN | flat      | xxx       | True      | False     |
#
# Estas son caracteristicas semánticas del conjunto de palabras encontradas en un determinado documento que fue transformado usando spacy. Como vemos, entontramos características como el lema de la palabra, su función dentro de la oración, si la palabra es un verbo, nombre, adjetivo, proposición, etc.

# %% [markdown]
# ### 2. Visualización
# Adicionalmente, podemos ver como es interpretada la oración y las dependencias al interior de la oración, cómo lo vemos en el siguiente código

# %%
from spacy import displacy #Importamos la libreria displacy para poder graficar 
sentence_spans = list(nlp_docs[3].sents) #Cremos una lista de palabras a partir de la oracion

# %%
displacy.render(sentence_spans, style='dep', jupyter=True, options={'distance': 140}) #Graficamos las dependencias e interpretación
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="6a75d3d4a4b946698a80033c7b5ace67-0" class="displacy" width="4250" height="557.0" direction="ltr" style="max-width: none; height: 557.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">Este</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">hotel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">está</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">situado</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">Bogotá,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">minutos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">pie</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">del</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1870">centro</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1870">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2010">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2010">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">convenciones</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2290">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2430">Corferias</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2430">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">y</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2710">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2710">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2990">minutos</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2990">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3130">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3130">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3270">coche</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3270">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">la</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3690">embajada</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3830">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3830">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="3970">Estados</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3970">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="4110">Unidos.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4110">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6a75d3d4a4b946698a80033c7b5ace67-0-0" stroke-width="2px" d="M70,422.0 C70,352.0 165.0,352.0 165.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font

# %%
displacy.render(sentence_spans, style='ent', jupyter=True) # Grafica para visualizar la deteccion de entidades
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/spacy/displacy/__init__.py:189: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# </br>Este hotel está situado en
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bogotá
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , a 5 minutos a pie del centro de convenciones de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Corferias
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  y a 5 minutos en coche de la embajada de
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Estados Unidos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . </div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ofrece habitaciones confortables con conexión Wi-Fi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# </br></div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Las habitaciones del Hotel Pasajero Suites
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# </br></div>
#
# </br></div>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">El Pasajero Suites está a 10 minutos en coche del
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aeropuerto internacional El Dorado
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  y a 15 minutos en coche del
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Museo del Oro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# </br></div></span>

# %% [markdown]
# ### 3. Tranformación numérica
#
# Ahora, vamos a ver como se representa un documento en nuestro vector numérico, que fué transformado por spacy en nuestra tarea de parsing. Un documento convertido en un vector numérico nos es de mucha utilidad al momento de efectuar tareas de clasificacion de texto o de inferencia de rankings como en este ejemplo. Tambien estos vectores son muy utilizados cuando queremos comparar la similitud entre dos documentos.

# %%
# Este seria una transformacion vectorial mediante TF-IDF, o una tecnica mas avanzada que efectuó spacy 
# al momento de generar nuestro objecto doc 

nlp_docs[3].vector
# Out:
# array([ 1.20482898e+00,  1.10522732e-01,  6.19889677e-01,  8.28116536e-01,
#         7.12487400e-01,  7.40799755e-02, -4.65785146e-01,  1.68049186e-01,
#         6.97081804e-01, -5.57429612e-01,  2.46727556e-01,  9.73027408e-01,
#         1.01136220e+00,  1.14661789e+00, -1.52123260e+00,  1.05496776e+00,
#         2.63637185e-01,  6.39321268e-01,  2.39508137e-01,  1.03144026e+00,
#        -3.77487510e-01, -8.53679538e-01, -5.05716443e-01,  7.14572549e-01,
#         4.72292956e-03,  4.01105344e-01,  4.20959145e-01,  1.78429520e+00,
#         5.85241497e-01, -1.83497930e+00,  3.71881306e-01, -6.54615998e-01,
#        -4.56284970e-01,  2.32364699e-01, -1.43773928e-01, -1.36908495e+00,
#         1.15863420e-01, -1.00800157e+00,  8.78069997e-01, -5.51854014e-01,
#         2.35715955e-01, -6.89187586e-01, -2.40998578e+00,  4.71363127e-01,
#        -1.16170514e+00,  9.96910751e-01, -4.60860431e-01, -3.93927917e-02,
#        -8.82215023e-01,  1.98569521e-01,  2.85739243e-01, -2.41725147e-01,
#         3.67027253e-01,  1.26788938e+00, -1.14205286e-01, -8.93317580e-01,
#        -5.96512377e-01,  8.52033436e-01, -1.44482255e+00, -5.14449459e-03,
#         1.62046254e-01,  9.07837629e-01, -2.68474132e-01, -5.80145046e-02,
#        -2.69512296e-01,  8.18691730e-01, -4.65691924e-01, -7.07929969e-01,
#        -7.51613796e-01, -1.14418554e+00,  1.38548744e+00, -1.43942177e-01,
#         6.55781567e-01,  2.55862504e-01, -3.01491380e-01,  7.50281930e-01,
#        -3.10354292e-01,  1.81668341e+00,  6.57610372e-02,  9.82895970e-01,
#        -1.40264225e+00, -9.85349536e-01, -1.17101085e+00,  1.80527198e+00,
#         4.75896001e-01,  6.88408494e-01,  1.15221107e+00, -3.32068950e-02,
#         1.79511571e+00, -7.02666998e-01, -3.66640478e-01,  7.84039438e-01,
#        -8.20491195e-01,  6.09878182e-01,  1.24691939e+00,  9.26973857e-03,
#        -4.27803248e-01, -7.66622901e-01, -1.30449092e+00, -4.35272306e-01,
#         5.15497386e-01,  1.50537670e+00,  2.94977933e-01,  9.38659132e-01,
#        -8.29840899e-01,  7.18353912e-02,  1.24254715e+00, -4.08115655e-01,
#         1.30629563e+00,  2.22020745e+00, -4.97736633e-01,  2.03918651e-01,
#         7.89529681e-01,  4.32662308e-01, -2.96992481e-01,  2.26481810e-01,
#        -1.52296692e-01,  3.33277702e-01,  2.25062579e-01, -1.73822418e-01,
#         4.54618514e-01,  4.72927727e-02, -3.65777105e-01,  5.29709697e-01,
#         3.90564382e-01, -3.76628816e-01,  5.75166464e-01, -9.83185053e-01,
#         1.24510431e+00, -4.83735092e-02, -1.38955593e-01, -1.88427103e+00,
#        -5.93716919e-01, -3.18613797e-01,  4.34708387e-01, -2.14133829e-01,
#         3.63841951e-01,  2.70409644e-01,  9.53671575e-01,  1.23128653e+00,
#         8.60964477e-01,  7.36015975e-01,  1.30937409e+00,  8.16807210e-01,
#        -9.55796957e-01, -3.52325618e-01,  1.92342252e-01, -4.78759229e-01,
#        -1.36901975e+00, -4.35444325e-01, -8.22251678e-01, -1.33432280e-02,
#        -4.72062044e-02,  1.87899816e+00,  4.76828188e-01, -8.30425084e-01,
#        -3.41976523e-01, -2.19205394e-01, -5.42741656e-01,  6.06289029e-01,
#        -4.55128133e-01, -4.54115480e-01,  3.03277582e-01,  1.06815040e+00,
#        -1.30135268e-01, -3.66360158e-01, -1.44238198e+00,  1.02777503e-01,
#         2.68913567e-01, -6.12170398e-01,  1.30195367e+00,  7.80668676e-01,
#        -2.36694530e-01,  7.86145926e-01,  5.12410343e-01,  1.88315058e+00,
#        -9.49940801e-01, -9.14210260e-01,  4.69740957e-01,  9.00257602e-02,
#         5.99291742e-01, -7.87811100e-01,  1.25172853e+00, -2.10014805e-01,
#        -4.25764859e-01, -6.48352265e-01,  3.02870244e-01,  1.09996390e+00,
#        -4.96099412e-01, -1.13861054e-01,  4.59559560e-01,  7.60857165e-01,
#        -9.50734854e-01,  8.86423111e-01,  3.85103732e-01,  1.92068294e-01,
#         3.84215951e-01,  1.14671871e-01, -9.82728004e-02, -6.34935260e-01,
#         6.90066218e-02, -9.86901999e-01, -4.44498360e-01, -8.84420037e-01,
#        -8.84768128e-01, -3.98086369e-01,  1.41123012e-01,  4.00035113e-01,
#        -9.21223238e-02, -6.77048624e-01, -1.14303851e+00,  1.34727433e-01,
#         1.15042412e+00,  3.65609229e-01, -3.16959888e-01,  1.24834800e+00,
#         9.10977125e-01,  1.61577976e+00, -1.02903104e+00, -1.78110167e-01,
#        -1.29687655e+00, -8.01046133e-01,  7.85090864e-01,  2.44035289e-01,
#         1.77317345e+00, -5.23143172e-01, -8.51336777e-01,  7.25372136e-01,
#        -4.73508149e-01,  9.54570949e-01, -5.72140468e-03,  4.38583106e-01,
#         1.13867545e+00,  3.70132998e-02,  2.31853753e-01, -7.67057836e-01,
#        -4.36006844e-01,  1.56540081e-01,  3.87435853e-01,  3.04685712e-01,
#         6.44123912e-01, -1.50160217e+00, -1.52238703e+00,  3.15625519e-01,
#         1.12553447e-01,  5.03845692e-01, -9.59211230e-01, -2.62981863e-03,
#         3.38655382e-01,  2.66969472e-01,  5.99349082e-01, -4.39386129e-01,
#        -6.18380070e-01,  2.64765334e+00,  1.64938915e+00, -3.89826089e-01,
#        -7.73990992e-04, -9.43429410e-01, -1.90052301e-01,  9.91503537e-01,
#        -6.52049482e-01,  1.20658958e+00, -5.80892503e-01, -2.72163332e-01,
#        -9.81728584e-02, -3.29391986e-01,  3.10060903e-02,  1.67848790e+00,
#         5.08893549e-01,  1.06053102e+00,  1.21268809e-01, -9.67046857e-01,
#         6.72777951e-01, -1.90869045e+00, -1.18014894e-01, -9.22161937e-01,
#        -7.47845769e-02,  1.29751134e+00,  8.24340701e-01, -1.19924784e+00,
#         2.26892203e-01,  1.84362233e-01,  2.09506691e-01,  5.54228187e-01,
#         5.61077118e-01,  1.68263233e+00,  3.50500405e-01,  1.45881036e-02,
#         4.97642577e-01, -4.76197630e-01, -5.15099838e-02,  1.94056794e-01,
#         2.63709575e-01, -5.11157036e-01,  1.32666266e+00, -1.34405768e+00,
#         8.05152059e-01, -5.11770658e-02,  3.06548893e-01,  5.43572865e-02],
#       dtype=float32)

# %% [markdown]
# Ahora, con esto en mente, vamos a validar que tan similares son dos descripciones de hotel:

# %%
print(nlp_docs[1], "<->", nlp_docs[2], nlp_docs[1].similarity(nlp_docs[2]))
# Out:
# El Hotel Fenix ​​Beach Cartagena se encuentra en la isla de Tierra Bomba, a 10 minutos en barco de Cartagena. El establecimiento dispone de playa, bar y restaurante.
# Las habitaciones cuentan con aire acondicionado, ventilador y baño privado con ducha. Algunas habitaciones gozan de vistas al jardín. El establecimiento sirve un delicioso desayuno americano que incluye huevos, diferentes tipos de pan, una bebida caliente y zumo natural.
# El Hotel Fenix ​​Beach Cartagena ofrece jardín, terraza, bar, piscina al aire libre y zona común con hamacas. Hay WiFi gratuita en todas las instalaciones.
# El alojamiento se encuentra en una isla, a 15 minutos del centro histórico de Cartagena y a 10 km del aeropuerto internacional Rafael Núñez.
#  <->
# El Mercure Bogotá Calle 100 se encuentra en la zona de El Chico, cerca del principal distrito financiero y de ocio, y ofrece un gimnasio y un restaurante en el centro de Bogotá. Dispone de sauna, bar, conexión Wi-Fi gratuita y aparcamiento gratuito. Hay un servicio gratuito de enlace con el aeropuerto disponible las 24 horas.
# Las habitaciones del Mercure Bogotá Calle 100 tienen suelo de moqueta, TV de pantalla plana, aire acondicionado, calefacción y muebles elegantes. Todas tienen baño privado.
# Todos los días se sirve un desayuno bufé. El restaurante del establecimiento prepara platos internacionales, especialidades colombianas y platos vegetarianos.
# El Mercure Bogotá Calle 100 se encuentra a 30 minutos en coche del aeropuerto internacional El Dorado.
#  0.954500631570073

# %% [markdown]
# Como vemos, estas dos descripciones son muy similares con un 95% de similaridad entre ellas!

# %% [markdown]
# ### 4. Ahora es tu turno
# Ahora es tu turno de usar estos conceptos. Utiliza spacy para buscar la similaridad entre descripciones de varios hoteles. Analiza si esta similaridad tiene sentido, y valida la similaridad convirtiendo la cadena de string de abajo. Que similaridad obtienes con ella al comparar cualquiera de los hoteles?

# %%
#Empieza desde acá
documento = "Hola, en este tutorial veras que tan similares o diferentes son dos textos utilizando la libreria spacy en python. Adios"
