# %% [markdown]
# # Proyecto

# %% [markdown]
# ### 1. Importación de librerías y archivos

# %%
# Importar las librerías necesarias según el análisis que se vaya a realizar
# Librería para manejo de datos convencional
import pandas as pd

# %%
# cargar los datos en csv
data= pd.read_csv('empleadosTecnologiaAlpes.csv', sep=';')
# Visualizar los datos
data.head()
# Out:
#    Edad Retirado       ViajesDeNegocio  TarifaSalarial  \
# 0    41       Si     Viaja-Pocas-Veces            1102
# 1    49       No  Viaja-Frecuentemente             279
# 2    37       Si     Viaja-Pocas-Veces            1373
# 3    33       No  Viaja-Frecuentemente            1392
# 4    27       No     Viaja-Pocas-Veces             591
#
#                  Departamento  DistanciaDesdeCasa  Educacion  \
# 0                      Ventas                   1          2
# 1  Investigacion & Desarrollo                   8          1
# 2  Investigacion & Desarrollo                   2          2
# 3  Investigacion & Desarrollo                   3          4
# 4  Investigacion & Desarrollo                   2          1
#
#         CampoEducacion  EmpleadosACargo  NumeroEmpleado  ...  HorasEstandar  \
# 0  Ciencias de la vida              1.0               1  ...             80
# 1  Ciencias de la vida              1.0               2  ...             80
# ...

# %% [markdown]
# ### 2. Análisis de la fuente de los datos
#
# ### 2.1. Registros y atributos

# %%
# Tamaño del dataset (filas, columnas)
data.shape
# Out:
# (1492, 36)

# %%
# Revisión de los atributos
data.columns
# Out:
# Index(['Edad', 'Retirado', 'ViajesDeNegocio', 'TarifaSalarial', 'Departamento',
#        'DistanciaDesdeCasa', 'Educacion', 'CampoEducacion', 'EmpleadosACargo',
#        'NumeroEmpleado', 'NivelSatisfaccion', 'Genero', 'SalarioPorHora',
#        'NivelInvolucramiento', 'NivelResponsabilidad', 'Rol',
#        'SatisfaccionTrabajo', 'EstadoCivil', 'SalarioMensual', 'TarifaMensual',
#        'NumEmpresasDondeTrabaja', 'MasDe18Horas', 'HorasExtra',
#        'PorcentajeIncrementoSalarioUltimoAnnio', 'NivelRendimiento',
#        'SatisfaccionEmpresa', 'HorasEstandar', 'PlanSalarioComplementario',
#        'TotalAnniosTrabajados', 'FormacionUltimoAnnio', 'BalanceTrabajoVida',
#        'FechaIngresoEmpresa', 'AnniosEnEmpresa', 'AnniosRolActual',
#        'AnniosDesdeUltimaPromocion', 'AnniosActualDirector'],
#       dtype='object')

# %% [markdown]
# ### 2.2. Tipos de datos

# %%
#identificar los tipos de datos
data.dtypes
# Out:
# Edad                                        int64
# Retirado                                   object
# ViajesDeNegocio                            object
# TarifaSalarial                              int64
# Departamento                               object
# DistanciaDesdeCasa                          int64
# Educacion                                   int64
# CampoEducacion                             object
# EmpleadosACargo                           float64
# NumeroEmpleado                              int64
# NivelSatisfaccion                           int64
# Genero                                     object
# SalarioPorHora                              int64
# NivelInvolucramiento                        int64
# NivelResponsabilidad                        int64
# Rol                                        object
# SatisfaccionTrabajo                         int64
# EstadoCivil                                object
# SalarioMensual                              int64
# ...

# %% [markdown]
# ### 3. Completitud
# ### 3.1. Identificar los atributos vacíos

# %%
# conteo de los datos vacíos por atributo
data.isna().sum()
# Out:
# Edad                                       0
# Retirado                                   0
# ViajesDeNegocio                            0
# TarifaSalarial                             0
# Departamento                               0
# DistanciaDesdeCasa                         0
# Educacion                                  0
# CampoEducacion                             0
# EmpleadosACargo                           20
# NumeroEmpleado                             0
# NivelSatisfaccion                          0
# Genero                                     7
# SalarioPorHora                             0
# NivelInvolucramiento                       0
# NivelResponsabilidad                       0
# Rol                                        0
# SatisfaccionTrabajo                        0
# EstadoCivil                               10
# SalarioMensual                             0
# TarifaMensual                              0
# NumEmpresasDondeTrabaja                    0
# ...

# %% [markdown]
# Los atributos empleadosACargo y estadoCivil presentan datos vacios.

# %%
# porcentaje de los datos vacíos por atributo
data[['EmpleadosACargo','EstadoCivil']].isna().sum()/len(data)
# Out:
# EmpleadosACargo    0.013405
# EstadoCivil        0.006702
# dtype: float64

# %% [markdown]
# ### 4. Análisis de datos duplicados

# %% [markdown]
# ### 4.1. Identificar el identificador único

# %%
### Contar los identificadores únicos
len(data['NumeroEmpleado'].unique())
# Out:
# 1470

# %% [markdown]
# El número de registros de nuestra fuente es de 1492 registros. Sin embargo, existen únicamente 1470 identificadores únicos. Un  claro indicador de que existen registros duplicados.

# %% [markdown]
# ### 4.2. Identificar los valores duplicados
#
# Debemos identificar dónde se encuentran los datos duplicados, podemos ver si en particular es en un solo atributo, o todos los atributos se encuentran duplicados, en las siguientes líneas vamos a desarrollar los dos análisis.

# %%
# revisar si el problema de duplicados está en un solo atributo, en este caso el número de orden
data[data.duplicated('NumeroEmpleado')]
# Out:
#       Edad Retirado       ViajesDeNegocio  TarifaSalarial  \
# 1201    23       Si     Viaja-Pocas-Veces             427
# 1438    23       Si  Viaja-Frecuentemente             638
# 1470    26       Si     Viaja-Pocas-Veces            1357
# 1471    20       Si  Viaja-Frecuentemente             871
# 1472    26       Si     Viaja-Pocas-Veces            1449
# 1473    26       Si     Viaja-Pocas-Veces             950
# 1474    26       Si  Viaja-Frecuentemente             575
# 1475    26       Si  Viaja-Frecuentemente             426
# 1476    26       Si     Viaja-Pocas-Veces             471
# 1477    20       Si     Viaja-Pocas-Veces            1362
# 1478    26       Si     Viaja-Pocas-Veces            1146
# 1480    26       Si  Viaja-Frecuentemente             887
# 1481    20       Si     Viaja-Pocas-Veces             500
# 1482    20       Si     Viaja-Pocas-Veces             129
# 1483    20       Si     Viaja-Pocas-Veces            1097
# ...

# %%
# revisar si hay registros donde todos los atributos están duplicados (son iguales)
data[data.duplicated()]
# Out:
#       Edad Retirado       ViajesDeNegocio  TarifaSalarial  \
# 1201    23       Si     Viaja-Pocas-Veces             427
# 1470    26       Si     Viaja-Pocas-Veces            1357
# 1471    20       Si  Viaja-Frecuentemente             871
# 1472    26       Si     Viaja-Pocas-Veces            1449
# 1473    26       Si     Viaja-Pocas-Veces             950
# 1474    26       Si  Viaja-Frecuentemente             575
# 1475    26       Si  Viaja-Frecuentemente             426
# 1476    26       Si     Viaja-Pocas-Veces             471
# 1477    20       Si     Viaja-Pocas-Veces            1362
# 1478    26       Si     Viaja-Pocas-Veces            1146
# 1480    26       Si  Viaja-Frecuentemente             887
# 1481    20       Si     Viaja-Pocas-Veces             500
# 1482    20       Si     Viaja-Pocas-Veces             129
# 1483    20       Si     Viaja-Pocas-Veces            1097
# 1484    26       Si              No-Viaja             265
# ...

# %% [markdown]
# Como vemos, existen 21 datos que se repiten en todos los atributos y también está el caso de 1 registros que se repiten en el número de orden, pero no necesariamente es igual en los otros atributos. Vamos a revisar estos casos en particular para entenderlos mejor.

# %%
# revisar los registros que tienen el número de orden duplicado pero no son iguales los valores de los dempas atributos
data[data.duplicated('NumeroEmpleado') & ~data.duplicated()]
# Out:
#       Edad Retirado       ViajesDeNegocio  TarifaSalarial Departamento  \
# 1438    23       Si  Viaja-Frecuentemente             638       Ventas
#
#       DistanciaDesdeCasa  Educacion CampoEducacion  EmpleadosACargo  \
# 1438                   9          3       Medicina              1.0
#
#       NumeroEmpleado  ...  HorasEstandar PlanSalarioComplementario  \
# 1438            2023  ...             80                         1
#
#       TotalAnniosTrabajados  FormacionUltimoAnnio  BalanceTrabajoVida  \
# 1438                      1                     3                   2
#
#      FechaIngresoEmpresa  AnniosEnEmpresa AnniosRolActual  \
# 1438          25/04/2020                1               0
#
#       AnniosDesdeUltimaPromocion  AnniosActualDirector
# 1438                           1                     0
#
# [1 rows x 36 columns]

# %%
data[data['NumeroEmpleado']==2023]
# Out:
#       Edad Retirado       ViajesDeNegocio  TarifaSalarial Departamento  \
# 1213    23       Si  Viaja-Frecuentemente             638       Ventas
# 1438    23       Si  Viaja-Frecuentemente             638       Ventas
#
#       DistanciaDesdeCasa  Educacion CampoEducacion  EmpleadosACargo  \
# 1213                   9          3       Mercadeo              1.0
# 1438                   9          3       Medicina              1.0
#
#       NumeroEmpleado  ...  HorasEstandar PlanSalarioComplementario  \
# 1213            2023  ...             80                         1
# 1438            2023  ...             80                         1
#
#       TotalAnniosTrabajados  FormacionUltimoAnnio  BalanceTrabajoVida  \
# 1213                      1                     3                   2
# 1438                      1                     3                   2
#
#      FechaIngresoEmpresa  AnniosEnEmpresa AnniosRolActual  \
# 1213          25/04/2020                1               0
# ...

# %%
# revisar en particular las órdenes que tiene este comportamiento
numero_ordenes_duplicadas=data[data.duplicated('NumeroEmpleado') & ~data.duplicated()]['NumeroEmpleado']
#numero_ordenes_duplicadas
data[data['NumeroEmpleado'].isin(numero_ordenes_duplicadas)]
# Out:
#       Edad Retirado       ViajesDeNegocio  TarifaSalarial Departamento  \
# 1213    23       Si  Viaja-Frecuentemente             638       Ventas
# 1438    23       Si  Viaja-Frecuentemente             638       Ventas
#
#       DistanciaDesdeCasa  Educacion CampoEducacion  EmpleadosACargo  \
# 1213                   9          3       Mercadeo              1.0
# 1438                   9          3       Medicina              1.0
#
#       NumeroEmpleado  ...  HorasEstandar PlanSalarioComplementario  \
# 1213            2023  ...             80                         1
# 1438            2023  ...             80                         1
#
#       TotalAnniosTrabajados  FormacionUltimoAnnio  BalanceTrabajoVida  \
# 1213                      1                     3                   2
# 1438                      1                     3                   2
#
#      FechaIngresoEmpresa  AnniosEnEmpresa AnniosRolActual  \
# 1213          25/04/2020                1               0
# ...

# %% [markdown]
# Vemos que los registros con índices:
# + 1213 y 1438
#
# Son exactamente los mismos registros, solamente que el campoEducacion en un registro es Mercadeo y en el otro Medecina.

# %% [markdown]
# ### 4.3. Eliminación de duplicados

# %%
#Eliminar los registros de columnas que están con la misma información
#data=data.drop([1438])
#data.head()

# %%
# eliminar el resto de duplicados
#data=data.drop_duplicates()
#data.head()

# %%
#validar que no existan duplicados
# longitud de la base
print(data.shape)
print(data.duplicated().sum())
# Out:
# (1492, 36)
# 21

# %% [markdown]
# Como vemos, después de eliminar los datos duplicados, se obtienen 1150 registros, que son los que desde un inicio deberíamos dejar como resultado para utilizar en análisis futuros.

# %% [markdown]
# ### 5. Estandarización

# %% [markdown]
# ### 5.1. Estandarizar un atributo tipo fecha

# %%
# revisar el formato del atributo  fecha_envío_límite
data[['FechaIngresoEmpresa']].head(30)
# Out:
#    FechaIngresoEmpresa
# 0           26/07/2015
# 1           15/02/2011
# 2            2/06/2021
# 3           26/09/2013
# 4            2/03/2019
# 5            8/07/2014
# 6            6/07/2020
# 7           15/08/2020
# 8           13/10/2012
# 9           15/07/2014
# 10          26/05/2016
# 11          11/07/2012
# 12           9/02/2016
# 13          15/03/2019
# 14          19/09/2017
# 15           2/02/2011
# 16           6/04/2015
# 17           1/05/2020
# 18           7/01/1996
# 19          14/11/2018
# 20           8/04/2017
# 21          15/05/2016
# 22           4/01/2009
# 23          23/04/2021
# 24          21/08/2017
# 25          16/02/2007
# 26           3/03/2011
# 27           3/09/2012
# 28          15/01/1999
# 29          26/08/2019

# %% [markdown]
# La fecha no presenta problemas en el formato, toda la columna posee el mismo formato.

# %%
# convertir a datetime el atributo FechaIngresoEmpresa
data['FechaIngresoEmpresa']=pd.to_datetime(data['FechaIngresoEmpresa'])
data[['FechaIngresoEmpresa']].head()
# Out:
# C:\Users\Edwar\AppData\Local\Temp\ipykernel_2596\1988937927.py:2: UserWarning: Parsing '26/07/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data['FechaIngresoEmpresa']=pd.to_datetime(data['FechaIngresoEmpresa'])
# C:\Users\Edwar\AppData\Local\Temp\ipykernel_2596\1988937927.py:2: UserWarning: Parsing '15/02/2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data['FechaIngresoEmpresa']=pd.to_datetime(data['FechaIngresoEmpresa'])
# C:\Users\Edwar\AppData\Local\Temp\ipykernel_2596\1988937927.py:2: UserWarning: Parsing '26/09/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   data['FechaIngresoEmpresa']=pd.to_datetime(data['FechaIngresoEmpresa'])
# ...

# %%
# revisar que el tipo de dato haya quedado correcto
data[['FechaIngresoEmpresa']].dtypes
# Out:
# FechaIngresoEmpresa    datetime64[ns]
# dtype: object

# %% [markdown]
# ### 5.3. Estandarizar un atributo categórico

# %%
#identificar las columnas de tipo string, si no se toma de la descripción inicial de la fuente de datos
data.select_dtypes(include='object').columns
# Out:
# Index(['Retirado', 'ViajesDeNegocio', 'Departamento', 'CampoEducacion',
#        'Genero', 'Rol', 'EstadoCivil', 'MasDe18Horas', 'HorasExtra'],
#       dtype='object')

# %%
# Consultar los datos del atributo Retirado
data['Retirado'].value_counts()
# Out:
# No    1233
# Si     259
# Name: Retirado, dtype: int64

# %% [markdown]
# No presenta problema.

# %%
# Consultar los datos del atributo ViajesDeNegocio
data['ViajesDeNegocio'].value_counts()
# Out:
# Viaja-Pocas-Veces       1057
# Viaja-Frecuentemente     284
# No-Viaja                 151
# Name: ViajesDeNegocio, dtype: int64

# %% [markdown]
# No presenta problema.

# %%
# Consultar los datos del atributo Departamento
data['Departamento'].value_counts()
# Out:
# Investigacion & Desarrollo    974
# Ventas                        451
# Talento Humano                 65
# Venta                           1
# Venta                           1
# Name: Departamento, dtype: int64

# %% [markdown]
# Presenta problema.

# %%
# Consultar los datos del atributo CampoEducacion
data['CampoEducacion'].value_counts()
# Out:
# Ciencias de la vida    612
# Medicina               471
# Mercadeo               159
# Nivel tecnico          136
# Otro                    82
# Talento Humano          27
# medicina                 2
# mercaeo                  2
# meDicina                 1
# Name: CampoEducacion, dtype: int64

# %% [markdown]
# Presenta problema.

# %%
# Consultar los datos del atributo Genero
data['Genero'].value_counts()
# Out:
# Masculino    896
# Femenino     589
# Name: Genero, dtype: int64

# %% [markdown]
# No presenta problema.

# %%
# Consultar los datos del atributo Rol
data['Rol'].value_counts()
# Out:
# Ejecutivo de ventas              329
# Cientifico de investigacion      297
# Tecnico de laboratorio           267
# Director de manufactura          145
# Representante atencion medica    131
# Director                         102
# Representante de ventas           87
# Director de investigacion         80
# Talento Humano                    54
# Name: Rol, dtype: int64

# %% [markdown]
# No presenta problema.

# %%
# Consultar los datos del atributo EstadoCivil
data['EstadoCivil'].value_counts()
# Out:
# Casado        672
# Soltero       482
# Divorciado    328
# Name: EstadoCivil, dtype: int64

# %% [markdown]
# No presenta problema.

# %%
# Consultar los datos del atributo MasDe18Horas
data['MasDe18Horas'].value_counts()
# Out:
# S    1492
# Name: MasDe18Horas, dtype: int64

# %% [markdown]
# No presenta problema.

# %%
# Consultar los datos del atributo HorasExtra
data['HorasExtra'].value_counts()
# Out:
# No    1062
# Si     430
# Name: HorasExtra, dtype: int64

# %% [markdown]
# No presenta problema.

# %% [markdown]
# Los atriutos CampoEducacion y Departamento presentan problemas de estandarizacion.

# %%
data['CampoEducacion'].value_counts()
# Out:
# Ciencias de la vida    612
# Medicina               471
# Mercadeo               159
# Nivel tecnico          136
# Otro                    82
# Talento Humano          27
# medicina                 2
# mercaeo                  2
# meDicina                 1
# Name: CampoEducacion, dtype: int64

# %%
data['CampoEducacion']= data['CampoEducacion'].apply(lambda x: x.capitalize())
data['CampoEducacion'].value_counts()
# Out:
# Ciencias de la vida    612
# Medicina               474
# Mercadeo               159
# Nivel tecnico          136
# Otro                    82
# Talento humano          27
# Mercaeo                  2
# Name: CampoEducacion, dtype: int64

# %% [markdown]
# El atributo CampoEducacion quedo corregido.

# %%
data['Departamento'].value_counts()
# Out:
# Investigacion & Desarrollo    974
# Ventas                        451
# Talento Humano                 65
# Venta                           1
# Venta                           1
# Name: Departamento, dtype: int64

# %%
def cambio(x):
    xnew=''
    if x=='Venta' or x=='Venta ':
        xnew='Ventas'
    else:
        xnew=x
    return xnew

# %%
data['Departamento'] = data['Departamento'].apply(cambio)
data['Departamento'].value_counts()
# Out:
# Investigacion & Desarrollo    974
# Ventas                        453
# Talento Humano                 65
# Name: Departamento, dtype: int64

# %% [markdown]
# El atributo Departamento quedo corregido.
